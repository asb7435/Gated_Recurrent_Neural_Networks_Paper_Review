# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
air_quality = fetch_ucirepo(id=360) 
# metadata 
print(air_quality.metadata) 
# variable information 
print(air_quality.variables)
# Out:
# {'uci_id': 360, 'name': 'Air Quality', 'repository_url': 'https://archive.ics.uci.edu/dataset/360/air+quality', 'data_url': 'https://archive.ics.uci.edu/static/public/360/data.csv', 'abstract': 'Contains the responses of a gas multisensor device deployed on the field in an Italian city. Hourly responses averages are recorded along with gas concentrations references from a certified analyzer. ', 'area': 'Computer Science', 'tasks': ['Regression'], 'characteristics': ['Multivariate', 'Time-Series'], 'num_instances': 9358, 'num_features': 15, 'feature_types': ['Real'], 'demographics': [], 'target_col': None, 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2008, 'last_updated': 'Sun Mar 10 2024', 'dataset_doi': '10.24432/C59K5F', 'creators': ['Saverio Vito'], 'intro_paper': {'title': 'On field calibration of an electronic nose for benzene estimation in an urban pollution monitoring scenario', 'authors': 'S. D. Vito, E. Massera, M. Piga, L. Martinotto, G. Francia', 'published_in': 'Sensors and Actuators B: Chemical', 'year': 2008, 'url': 'https://www.semanticscholar.org/paper/a90a54a39ff934772df57771a0012981f355949d', 'doi': '10.1016/j.snb.2007.09.060'}, 'additional_info': {'summary': 'The dataset contains 9358 instances of hourly averaged responses from an array of 5 metal oxide chemical sensors embedded in an Air Quality Chemical Multisensor Device. The device was located on the field in a significantly polluted area, at road level,within an Italian city. Data were recorded from March 2004 to February 2005 (one year)representing the longest freely available recordings of on field deployed air quality chemical sensor devices responses. Ground Truth hourly averaged concentrations for CO, Non Metanic Hydrocarbons, Benzene, Total Nitrogen Oxides (NOx) and Nitrogen Dioxide (NO2)  and were provided by a co-located reference certified analyzer. Evidences of cross-sensitivities as well as both concept and sensor drifts are present as described in De Vito et al., Sens. And Act. B, Vol. 129,2,2008 (citation required) eventually affecting sensors concentration estimation capabilities. Missing values are tagged with -200 value.\r\nThis dataset can be used exclusively for research purposes. Commercial purposes are fully excluded.\r\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '0 Date\t(DD/MM/YYYY)\r\n1 Time\t(HH.MM.SS)\r\n2 True hourly averaged concentration CO in mg/m^3  (reference analyzer)\r\n3 PT08.S1 (tin oxide)  hourly averaged sensor response (nominally  CO targeted)\t\r\n4 True hourly averaged overall Non Metanic HydroCarbons concentration in microg/m^3 (reference analyzer)\r\n5 True hourly averaged Benzene concentration  in microg/m^3 (reference analyzer)\r\n6 PT08.S2 (titania) hourly averaged sensor response (nominally NMHC targeted)\t\r\n7 True hourly averaged NOx concentration  in ppb (reference analyzer)\r\n8 PT08.S3 (tungsten oxide) hourly averaged sensor response (nominally NOx targeted) \r\n9 True hourly averaged NO2 concentration in microg/m^3 (reference analyzer)\t\r\n10 PT08.S4 (tungsten oxide) hourly averaged sensor response (nominally NO2 targeted)\t\r\n11 PT08.S5 (indium oxide) hourly averaged sensor response (nominally O3 targeted)\r\n12 Temperature in Â°C\t\r\n13 Relative Humidity (%) \t\r\n14 AH Absolute Humidity\r\n', 'citation': None}}
#              name     role         type demographic  \
# 0            Date  Feature         Date        None
# 1            Time  Feature  Categorical        None
# 2          CO(GT)  Feature      Integer        None
# 3     PT08.S1(CO)  Feature  Categorical        None
# 4        NMHC(GT)  Feature      Integer        None
# 5        C6H6(GT)  Feature   Continuous        None
# 6   PT08.S2(NMHC)  Feature  Categorical        None
# 7         NOx(GT)  Feature      Integer        None
# 8    PT08.S3(NOx)  Feature  Categorical        None
# 9         NO2(GT)  Feature      Integer        None
# 10   PT08.S4(NO2)  Feature  Categorical        None
# 11    PT08.S5(O3)  Feature  Categorical        None
# 12              T  Feature   Continuous        None
# 13             RH  Feature   Continuous        None
# 14             AH  Feature   Continuous        None
#
#                                           description       units  \
# 0                                                None        None
# 1                                                None        None
# 2   True hourly averaged concentration CO in mg/m^...      mg/m^3
# 3   hourly averaged sensor response (nominally  CO...        None
# 4   True hourly averaged overall Non Metanic Hydro...  microg/m^3
# 5   True hourly averaged Benzene concentration  in...  microg/m^3
# 6   hourly averaged sensor response (nominally NMH...        None
# 7   True hourly averaged NOx concentration  in ppb...         ppb
# 8   hourly averaged sensor response (nominally NOx...        None
# 9   True hourly averaged NO2 concentration in micr...  microg/m^3
# 10  hourly averaged sensor response (nominally NO2...        None
# 11  hourly averaged sensor response (nominally O3 ...        None
# 12                                        Temperature          °C
# 13                                  Relative Humidity           %
# 14                                  Absolute Humidity        None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# 5              no
# 6              no
# 7              no
# 8              no
# 9              no
# 10             no
# 11             no
# 12             no
# 13             no
# 14             no

# %%
y = air_quality.data.features['C6H6(GT)']
X = air_quality.data.features.drop(columns=['C6H6(GT)'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# 문자열 데이터가 포함된 열 확인
for column in X.columns:
    if X[column].dtype == 'object':
        print(f"Column {column} has string data: {X[column].unique()[:5]}")

# 예를 들어 특정 열이 여전히 문자열을 포함하고 있다면, 제거하거나 변환해야 합니다.
# 문자열 열을 드롭합니다.
X = X.select_dtypes(exclude=['object'])

# 모든 열이 수치형인지 다시 확인합니다.
print(X.dtypes)


# 데이터 스케일링
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 시계열 데이터로 변환하기 위해 시퀀스 생성
time_steps = 10

def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps), :])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y, time_steps)

# 데이터셋을 훈련, 검증, 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, shuffle=False)
# Out:
# Column Date has string data: ['3/10/2004' '3/11/2004' '3/12/2004' '3/13/2004' '3/14/2004']
# Column Time has string data: ['18:00:00' '19:00:00' '20:00:00' '21:00:00' '22:00:00']
# CO(GT)           float64
# PT08.S1(CO)        int64
# NMHC(GT)           int64
# PT08.S2(NMHC)      int64
# NOx(GT)            int64
# PT08.S3(NOx)       int64
# NO2(GT)            int64
# PT08.S4(NO2)       int64
# PT08.S5(O3)        int64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout
from keras.optimizers import RMSprop
from keras.metrics import MeanSquaredError
from keras.callbacks import EarlyStopping

# LSTM 모델 정의
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    optimizer = RMSprop(learning_rate=0.001, clipnorm=1.0)  # Gradient clipping added
    model.compile(optimizer=RMSprop(), loss='mse', metrics=[MeanSquaredError()])
    return model

# GRU 모델 정의
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(50, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    optimizer = RMSprop(learning_rate=0.001, clipnorm=1.0)  # Gradient clipping added
    model.compile(optimizer=RMSprop(), loss='mse', metrics=[MeanSquaredError()])
    return model

# SimpleRNN(tanh) 모델 정의
def build_rnn_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(50, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    optimizer = RMSprop(learning_rate=0.001, clipnorm=1.0)  # Gradient clipping added
    model.compile(optimizer=RMSprop(), loss='mse', metrics=[MeanSquaredError()])
    return model

# 조기 종료 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련
lstm_model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
gru_model = build_gru_model((X_train.shape[1], X_train.shape[2]))
rnn_model = build_rnn_model((X_train.shape[1], X_train.shape[2]))

lstm_history = lstm_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
gru_history = gru_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
rnn_history = rnn_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 234/234 [==============================] - 3s 6ms/step - loss: 1513.8451 - mean_squared_error: 1513.8451 - val_loss: 1653.7120 - val_mean_squared_error: 1653.7120
# Epoch 2/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1356.2522 - mean_squared_error: 1356.2522 - val_loss: 1519.0198 - val_mean_squared_error: 1519.0198
# Epoch 3/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1247.0642 - mean_squared_error: 1247.0642 - val_loss: 1397.1599 - val_mean_squared_error: 1397.1599
# Epoch 4/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1138.9786 - mean_squared_error: 1138.9786 - val_loss: 1288.4924 - val_mean_squared_error: 1288.4924
# Epoch 5/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1049.2894 - mean_squared_error: 1049.2894 - val_loss: 1183.0480 - val_mean_squared_error: 1183.0480
# Epoch 6/100
# 234/234 [==============================] - 1s 4ms/step - loss: 959.7405 - mean_squared_error: 959.7405 - val_loss: 1075.5764 - val_mean_squared_error: 1075.5764
# Epoch 7/100
# 234/234 [==============================] - 1s 4ms/step - loss: 884.8392 - mean_squared_error: 884.8392 - val_loss: 977.3071 - val_mean_squared_error: 977.3071
# Epoch 8/100
# 234/234 [==============================] - 1s 4ms/step - loss: 808.3938 - mean_squared_error: 808.3938 - val_loss: 892.6539 - val_mean_squared_error: 892.6539
# Epoch 9/100
# 234/234 [==============================] - 1s 4ms/step - loss: 748.1541 - mean_squared_error: 748.1541 - val_loss: 815.1853 - val_mean_squared_error: 815.1853
# Epoch 10/100
# 234/234 [==============================] - 1s 4ms/step - loss: 674.5137 - mean_squared_error: 674.5137 - val_loss: 749.1077 - val_mean_squared_error: 749.1077
# Epoch 11/100
# 234/234 [==============================] - 1s 4ms/step - loss: 626.5958 - mean_squared_error: 626.5958 - val_loss: 680.3588 - val_mean_squared_error: 680.3588
# Epoch 12/100
# 234/234 [==============================] - 1s 4ms/step - loss: 579.4062 - mean_squared_error: 579.4062 - val_loss: 609.7147 - val_mean_squared_error: 609.7147
# Epoch 13/100
# 234/234 [==============================] - 1s 4ms/step - loss: 533.3359 - mean_squared_error: 533.3359 - val_loss: 551.6382 - val_mean_squared_error: 551.6382
# Epoch 14/100
# 234/234 [==============================] - 1s 4ms/step - loss: 488.4857 - mean_squared_error: 488.4857 - val_loss: 500.7665 - val_mean_squared_error: 500.7665
# Epoch 15/100
# 234/234 [==============================] - 1s 4ms/step - loss: 453.0486 - mean_squared_error: 453.0486 - val_loss: 448.9876 - val_mean_squared_error: 448.9876
# Epoch 16/100
# 234/234 [==============================] - 1s 4ms/step - loss: 417.0643 - mean_squared_error: 417.0643 - val_loss: 410.5554 - val_mean_squared_error: 410.5554
# Epoch 17/100
# 234/234 [==============================] - 1s 4ms/step - loss: 382.7482 - mean_squared_error: 382.7482 - val_loss: 372.5092 - val_mean_squared_error: 372.5092
# Epoch 18/100
# 234/234 [==============================] - 1s 4ms/step - loss: 358.6441 - mean_squared_error: 358.6441 - val_loss: 340.8079 - val_mean_squared_error: 340.8079
# Epoch 19/100
# 234/234 [==============================] - 1s 4ms/step - loss: 327.7377 - mean_squared_error: 327.7377 - val_loss: 315.3347 - val_mean_squared_error: 315.3347
# Epoch 20/100
# 234/234 [==============================] - 1s 4ms/step - loss: 311.2797 - mean_squared_error: 311.2797 - val_loss: 282.1020 - val_mean_squared_error: 282.1020
# Epoch 21/100
# 234/234 [==============================] - 1s 4ms/step - loss: 291.4907 - mean_squared_error: 291.4907 - val_loss: 261.0287 - val_mean_squared_error: 261.0287
# Epoch 22/100
# 234/234 [==============================] - 1s 4ms/step - loss: 280.5751 - mean_squared_error: 280.5751 - val_loss: 243.1225 - val_mean_squared_error: 243.1225
# Epoch 23/100
# 234/234 [==============================] - 1s 4ms/step - loss: 263.3044 - mean_squared_error: 263.3044 - val_loss: 230.9747 - val_mean_squared_error: 230.9747
# Epoch 24/100
# 234/234 [==============================] - 1s 4ms/step - loss: 258.1862 - mean_squared_error: 258.1862 - val_loss: 222.3348 - val_mean_squared_error: 222.3348
# Epoch 25/100
# 234/234 [==============================] - 1s 4ms/step - loss: 238.6283 - mean_squared_error: 238.6283 - val_loss: 203.8116 - val_mean_squared_error: 203.8116
# Epoch 26/100
# 234/234 [==============================] - 1s 4ms/step - loss: 232.9409 - mean_squared_error: 232.9409 - val_loss: 192.3612 - val_mean_squared_error: 192.3612
# Epoch 27/100
# 234/234 [==============================] - 1s 4ms/step - loss: 222.5034 - mean_squared_error: 222.5034 - val_loss: 182.9020 - val_mean_squared_error: 182.9020
# Epoch 28/100
# 234/234 [==============================] - 1s 4ms/step - loss: 225.0079 - mean_squared_error: 225.0079 - val_loss: 174.6278 - val_mean_squared_error: 174.6278
# Epoch 29/100
# 234/234 [==============================] - 1s 4ms/step - loss: 217.2902 - mean_squared_error: 217.2902 - val_loss: 168.3410 - val_mean_squared_error: 168.3410
# Epoch 30/100
# 234/234 [==============================] - 1s 4ms/step - loss: 212.3923 - mean_squared_error: 212.3923 - val_loss: 166.1751 - val_mean_squared_error: 166.1751
# Epoch 31/100
# 234/234 [==============================] - 1s 4ms/step - loss: 206.0540 - mean_squared_error: 206.0540 - val_loss: 160.9538 - val_mean_squared_error: 160.9538
# Epoch 32/100
# 234/234 [==============================] - 1s 4ms/step - loss: 199.9701 - mean_squared_error: 199.9701 - val_loss: 154.8142 - val_mean_squared_error: 154.8142
# Epoch 33/100
# 234/234 [==============================] - 1s 4ms/step - loss: 194.1801 - mean_squared_error: 194.1801 - val_loss: 163.1631 - val_mean_squared_error: 163.1631
# Epoch 34/100
# 234/234 [==============================] - 1s 4ms/step - loss: 199.7329 - mean_squared_error: 199.7329 - val_loss: 155.0042 - val_mean_squared_error: 155.0042
# Epoch 35/100
# 234/234 [==============================] - 1s 4ms/step - loss: 193.8031 - mean_squared_error: 193.8031 - val_loss: 148.0986 - val_mean_squared_error: 148.0986
# Epoch 36/100
# 234/234 [==============================] - 1s 5ms/step - loss: 198.8765 - mean_squared_error: 198.8765 - val_loss: 146.3940 - val_mean_squared_error: 146.3940
# Epoch 37/100
# 234/234 [==============================] - 1s 5ms/step - loss: 190.2457 - mean_squared_error: 190.2457 - val_loss: 151.9403 - val_mean_squared_error: 151.9403
# Epoch 38/100
# 234/234 [==============================] - 1s 5ms/step - loss: 191.1311 - mean_squared_error: 191.1311 - val_loss: 146.8959 - val_mean_squared_error: 146.8959
# Epoch 39/100
# 234/234 [==============================] - 1s 5ms/step - loss: 188.0915 - mean_squared_error: 188.0915 - val_loss: 143.2053 - val_mean_squared_error: 143.2053
# Epoch 40/100
# 234/234 [==============================] - 1s 5ms/step - loss: 189.1543 - mean_squared_error: 189.1543 - val_loss: 143.0998 - val_mean_squared_error: 143.0998
# Epoch 41/100
# 234/234 [==============================] - 1s 4ms/step - loss: 190.0963 - mean_squared_error: 190.0963 - val_loss: 143.2725 - val_mean_squared_error: 143.2725
# Epoch 42/100
# 234/234 [==============================] - 1s 4ms/step - loss: 189.6032 - mean_squared_error: 189.6032 - val_loss: 145.0086 - val_mean_squared_error: 145.0086
# Epoch 43/100
# 234/234 [==============================] - 1s 4ms/step - loss: 186.1960 - mean_squared_error: 186.1960 - val_loss: 143.2303 - val_mean_squared_error: 143.2303
# Epoch 44/100
# 234/234 [==============================] - 1s 4ms/step - loss: 178.7235 - mean_squared_error: 178.7235 - val_loss: 144.8001 - val_mean_squared_error: 144.8001
# Epoch 45/100
# 234/234 [==============================] - 1s 4ms/step - loss: 187.2672 - mean_squared_error: 187.2672 - val_loss: 143.8277 - val_mean_squared_error: 143.8277
# Epoch 1/100
# 234/234 [==============================] - 2s 5ms/step - loss: 1467.8783 - mean_squared_error: 1467.8783 - val_loss: 1616.3480 - val_mean_squared_error: 1616.3480
# Epoch 2/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1315.3883 - mean_squared_error: 1315.3883 - val_loss: 1493.8373 - val_mean_squared_error: 1493.8373
# Epoch 3/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1214.4309 - mean_squared_error: 1214.4309 - val_loss: 1376.8560 - val_mean_squared_error: 1376.8560
# Epoch 4/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1119.9215 - mean_squared_error: 1119.9215 - val_loss: 1274.7578 - val_mean_squared_error: 1274.7578
# Epoch 5/100
# 234/234 [==============================] - 1s 4ms/step - loss: 1043.1003 - mean_squared_error: 1043.1003 - val_loss: 1177.5909 - val_mean_squared_error: 1177.5909
# Epoch 6/100
# 234/234 [==============================] - 1s 4ms/step - loss: 949.8939 - mean_squared_error: 949.8939 - val_loss: 1069.5560 - val_mean_squared_error: 1069.5560
# Epoch 7/100
# 234/234 [==============================] - 1s 4ms/step - loss: 867.1808 - mean_squared_error: 867.1808 - val_loss: 969.3065 - val_mean_squared_error: 969.3065
# Epoch 8/100
# 234/234 [==============================] - 1s 4ms/step - loss: 785.3130 - mean_squared_error: 785.3130 - val_loss: 882.4920 - val_mean_squared_error: 882.4920
# Epoch 9/100
# 234/234 [==============================] - 1s 3ms/step - loss: 710.0365 - mean_squared_error: 710.0365 - val_loss: 789.5048 - val_mean_squared_error: 789.5048
# Epoch 10/100
# 234/234 [==============================] - 1s 4ms/step - loss: 650.4177 - mean_squared_error: 650.4177 - val_loss: 708.9229 - val_mean_squared_error: 708.9229
# Epoch 11/100
# 234/234 [==============================] - 1s 4ms/step - loss: 587.3709 - mean_squared_error: 587.3709 - val_loss: 636.9648 - val_mean_squared_error: 636.9648
# Epoch 12/100
# 234/234 [==============================] - 1s 4ms/step - loss: 542.2967 - mean_squared_error: 542.2967 - val_loss: 573.2406 - val_mean_squared_error: 573.2406
# Epoch 13/100
# 234/234 [==============================] - 1s 4ms/step - loss: 485.4870 - mean_squared_error: 485.4870 - val_loss: 513.2401 - val_mean_squared_error: 513.2401
# Epoch 14/100
# 234/234 [==============================] - 1s 4ms/step - loss: 446.7411 - mean_squared_error: 446.7412 - val_loss: 463.4282 - val_mean_squared_error: 463.4282
# Epoch 15/100
# 234/234 [==============================] - 1s 4ms/step - loss: 413.2819 - mean_squared_error: 413.2819 - val_loss: 412.3857 - val_mean_squared_error: 412.3857
# Epoch 16/100
# 234/234 [==============================] - 1s 3ms/step - loss: 373.6568 - mean_squared_error: 373.6568 - val_loss: 374.6482 - val_mean_squared_error: 374.6482
# Epoch 17/100
# 234/234 [==============================] - 1s 3ms/step - loss: 343.4502 - mean_squared_error: 343.4502 - val_loss: 334.5246 - val_mean_squared_error: 334.5246
# Epoch 18/100
# 234/234 [==============================] - 1s 4ms/step - loss: 323.4415 - mean_squared_error: 323.4415 - val_loss: 300.2329 - val_mean_squared_error: 300.2329
# Epoch 19/100
# 234/234 [==============================] - 1s 4ms/step - loss: 302.1483 - mean_squared_error: 302.1483 - val_loss: 273.7215 - val_mean_squared_error: 273.7215
# Epoch 20/100
# 234/234 [==============================] - 1s 4ms/step - loss: 268.5340 - mean_squared_error: 268.5340 - val_loss: 248.7434 - val_mean_squared_error: 248.7434
# Epoch 21/100
# 234/234 [==============================] - 1s 4ms/step - loss: 259.2122 - mean_squared_error: 259.2122 - val_loss: 226.9834 - val_mean_squared_error: 226.9834
# Epoch 22/100
# 234/234 [==============================] - 1s 4ms/step - loss: 244.7668 - mean_squared_error: 244.7668 - val_loss: 210.5703 - val_mean_squared_error: 210.5703
# Epoch 23/100
# 234/234 [==============================] - 1s 4ms/step - loss: 236.6076 - mean_squared_error: 236.6076 - val_loss: 196.8497 - val_mean_squared_error: 196.8497
# Epoch 24/100
# 234/234 [==============================] - 1s 4ms/step - loss: 221.6080 - mean_squared_error: 221.6080 - val_loss: 192.4919 - val_mean_squared_error: 192.4919
# Epoch 25/100
# 234/234 [==============================] - 1s 4ms/step - loss: 207.5851 - mean_squared_error: 207.5851 - val_loss: 177.4118 - val_mean_squared_error: 177.4118
# Epoch 26/100
# 234/234 [==============================] - 1s 4ms/step - loss: 205.7809 - mean_squared_error: 205.7809 - val_loss: 170.5832 - val_mean_squared_error: 170.5832
# Epoch 27/100
# 234/234 [==============================] - 1s 4ms/step - loss: 204.1721 - mean_squared_error: 204.1721 - val_loss: 164.9315 - val_mean_squared_error: 164.9315
# Epoch 28/100
# 234/234 [==============================] - 1s 4ms/step - loss: 199.8237 - mean_squared_error: 199.8237 - val_loss: 160.3479 - val_mean_squared_error: 160.3479
# Epoch 29/100
# 234/234 [==============================] - 1s 4ms/step - loss: 197.5968 - mean_squared_error: 197.5968 - val_loss: 159.4459 - val_mean_squared_error: 159.4459
# Epoch 30/100
# 234/234 [==============================] - 1s 4ms/step - loss: 194.7816 - mean_squared_error: 194.7816 - val_loss: 155.2664 - val_mean_squared_error: 155.2664
# Epoch 31/100
# 234/234 [==============================] - 1s 4ms/step - loss: 189.9935 - mean_squared_error: 189.9935 - val_loss: 153.1900 - val_mean_squared_error: 153.1900
# Epoch 32/100
# 234/234 [==============================] - 1s 4ms/step - loss: 196.0158 - mean_squared_error: 196.0158 - val_loss: 151.2226 - val_mean_squared_error: 151.2226
# Epoch 33/100
# 234/234 [==============================] - 1s 4ms/step - loss: 185.1081 - mean_squared_error: 185.1081 - val_loss: 152.9217 - val_mean_squared_error: 152.9217
# Epoch 34/100
# 234/234 [==============================] - 1s 3ms/step - loss: 183.8415 - mean_squared_error: 183.8415 - val_loss: 153.3498 - val_mean_squared_error: 153.3498
# Epoch 35/100
# 234/234 [==============================] - 1s 4ms/step - loss: 183.2917 - mean_squared_error: 183.2917 - val_loss: 151.2948 - val_mean_squared_error: 151.2948
# Epoch 36/100
# 234/234 [==============================] - 1s 4ms/step - loss: 178.1345 - mean_squared_error: 178.1345 - val_loss: 149.0910 - val_mean_squared_error: 149.0910
# Epoch 37/100
# 234/234 [==============================] - 1s 4ms/step - loss: 182.2234 - mean_squared_error: 182.2234 - val_loss: 149.5809 - val_mean_squared_error: 149.5809
# Epoch 38/100
# 234/234 [==============================] - 1s 4ms/step - loss: 184.3468 - mean_squared_error: 184.3468 - val_loss: 146.5284 - val_mean_squared_error: 146.5284
# Epoch 39/100
# 234/234 [==============================] - 1s 4ms/step - loss: 184.1159 - mean_squared_error: 184.1159 - val_loss: 146.6129 - val_mean_squared_error: 146.6129
# Epoch 40/100
# 234/234 [==============================] - 1s 4ms/step - loss: 181.0106 - mean_squared_error: 181.0106 - val_loss: 145.7471 - val_mean_squared_error: 145.7471
# Epoch 41/100
# 234/234 [==============================] - 1s 4ms/step - loss: 181.8030 - mean_squared_error: 181.8030 - val_loss: 147.1424 - val_mean_squared_error: 147.1424
# Epoch 42/100
# 234/234 [==============================] - 1s 4ms/step - loss: 184.9909 - mean_squared_error: 184.9909 - val_loss: 145.6967 - val_mean_squared_error: 145.6967
# Epoch 43/100
# 234/234 [==============================] - 1s 4ms/step - loss: 178.6777 - mean_squared_error: 178.6777 - val_loss: 144.8130 - val_mean_squared_error: 144.8130
# Epoch 44/100
# 234/234 [==============================] - 1s 4ms/step - loss: 181.9684 - mean_squared_error: 181.9684 - val_loss: 144.0993 - val_mean_squared_error: 144.0993
# Epoch 45/100
# 234/234 [==============================] - 1s 4ms/step - loss: 182.7411 - mean_squared_error: 182.7411 - val_loss: 144.2825 - val_mean_squared_error: 144.2825
# Epoch 46/100
# 234/234 [==============================] - 1s 4ms/step - loss: 185.8749 - mean_squared_error: 185.8749 - val_loss: 146.1512 - val_mean_squared_error: 146.1512
# Epoch 47/100
# 234/234 [==============================] - 1s 4ms/step - loss: 182.1771 - mean_squared_error: 182.1771 - val_loss: 143.0176 - val_mean_squared_error: 143.0176
# Epoch 48/100
# 234/234 [==============================] - 1s 4ms/step - loss: 176.4826 - mean_squared_error: 176.4826 - val_loss: 144.8069 - val_mean_squared_error: 144.8069
# Epoch 49/100
# 234/234 [==============================] - 1s 4ms/step - loss: 179.9385 - mean_squared_error: 179.9385 - val_loss: 145.7363 - val_mean_squared_error: 145.7363
# Epoch 50/100
# 234/234 [==============================] - 1s 4ms/step - loss: 177.3099 - mean_squared_error: 177.3099 - val_loss: 144.9034 - val_mean_squared_error: 144.9034
# Epoch 51/100
# 234/234 [==============================] - 1s 4ms/step - loss: 185.9013 - mean_squared_error: 185.9013 - val_loss: 143.0826 - val_mean_squared_error: 143.0826
# Epoch 52/100
# 234/234 [==============================] - 1s 3ms/step - loss: 181.4769 - mean_squared_error: 181.4769 - val_loss: 144.3553 - val_mean_squared_error: 144.3553
# Epoch 1/100
# 234/234 [==============================] - 1s 2ms/step - loss: 1473.5619 - mean_squared_error: 1473.5619 - val_loss: 1671.8062 - val_mean_squared_error: 1671.8062
# Epoch 2/100
# 234/234 [==============================] - 0s 2ms/step - loss: 1348.3376 - mean_squared_error: 1348.3376 - val_loss: 1531.3456 - val_mean_squared_error: 1531.3456
# Epoch 3/100
# 234/234 [==============================] - 0s 2ms/step - loss: 1240.9391 - mean_squared_error: 1240.9391 - val_loss: 1405.8046 - val_mean_squared_error: 1405.8046
# Epoch 4/100
# 234/234 [==============================] - 0s 2ms/step - loss: 1138.8430 - mean_squared_error: 1138.8430 - val_loss: 1293.3579 - val_mean_squared_error: 1293.3579
# Epoch 5/100
# 234/234 [==============================] - 0s 2ms/step - loss: 1061.3035 - mean_squared_error: 1061.3035 - val_loss: 1188.6906 - val_mean_squared_error: 1188.6906
# Epoch 6/100
# 234/234 [==============================] - 0s 2ms/step - loss: 972.6695 - mean_squared_error: 972.6695 - val_loss: 1094.5728 - val_mean_squared_error: 1094.5728
# Epoch 7/100
# 234/234 [==============================] - 0s 2ms/step - loss: 890.9664 - mean_squared_error: 890.9664 - val_loss: 994.8532 - val_mean_squared_error: 994.8532
# Epoch 8/100
# 234/234 [==============================] - 0s 2ms/step - loss: 821.5716 - mean_squared_error: 821.5716 - val_loss: 908.2200 - val_mean_squared_error: 908.2200
# Epoch 9/100
# 234/234 [==============================] - 0s 2ms/step - loss: 757.3629 - mean_squared_error: 757.3629 - val_loss: 824.2141 - val_mean_squared_error: 824.2141
# Epoch 10/100
# 234/234 [==============================] - 1s 2ms/step - loss: 693.1334 - mean_squared_error: 693.1334 - val_loss: 747.8920 - val_mean_squared_error: 747.8920
# Epoch 11/100
# 234/234 [==============================] - 0s 2ms/step - loss: 628.6967 - mean_squared_error: 628.6967 - val_loss: 681.6138 - val_mean_squared_error: 681.6138
# Epoch 12/100
# 234/234 [==============================] - 0s 2ms/step - loss: 587.1264 - mean_squared_error: 587.1264 - val_loss: 615.7057 - val_mean_squared_error: 615.7057
# Epoch 13/100
# 234/234 [==============================] - 1s 2ms/step - loss: 540.0681 - mean_squared_error: 540.0681 - val_loss: 556.8675 - val_mean_squared_error: 556.8675
# Epoch 14/100
# 234/234 [==============================] - 0s 2ms/step - loss: 557.0632 - mean_squared_error: 557.0632 - val_loss: 523.0891 - val_mean_squared_error: 523.0891
# Epoch 15/100
# 234/234 [==============================] - 0s 2ms/step - loss: 475.8520 - mean_squared_error: 475.8520 - val_loss: 481.4216 - val_mean_squared_error: 481.4216
# Epoch 16/100
# 234/234 [==============================] - 0s 2ms/step - loss: 445.0218 - mean_squared_error: 445.0218 - val_loss: 422.5421 - val_mean_squared_error: 422.5421
# Epoch 17/100
# 234/234 [==============================] - 0s 2ms/step - loss: 391.0477 - mean_squared_error: 391.0477 - val_loss: 390.6758 - val_mean_squared_error: 390.6758
# Epoch 18/100
# 234/234 [==============================] - 1s 2ms/step - loss: 376.1226 - mean_squared_error: 376.1226 - val_loss: 355.1718 - val_mean_squared_error: 355.1718
# Epoch 19/100
# 234/234 [==============================] - 0s 2ms/step - loss: 349.2220 - mean_squared_error: 349.2220 - val_loss: 320.8630 - val_mean_squared_error: 320.8630
# Epoch 20/100
# 234/234 [==============================] - 0s 2ms/step - loss: 353.9838 - mean_squared_error: 353.9838 - val_loss: 296.3318 - val_mean_squared_error: 296.3318
# Epoch 21/100
# 234/234 [==============================] - 0s 2ms/step - loss: 350.0821 - mean_squared_error: 350.0821 - val_loss: 278.8022 - val_mean_squared_error: 278.8022
# Epoch 22/100
# 234/234 [==============================] - 0s 2ms/step - loss: 362.1145 - mean_squared_error: 362.1145 - val_loss: 260.5222 - val_mean_squared_error: 260.5222
# Epoch 23/100
# 234/234 [==============================] - 0s 2ms/step - loss: 292.9426 - mean_squared_error: 292.9426 - val_loss: 243.7274 - val_mean_squared_error: 243.7274
# Epoch 24/100
# 234/234 [==============================] - 0s 2ms/step - loss: 276.2777 - mean_squared_error: 276.2777 - val_loss: 286.8397 - val_mean_squared_error: 286.8397
# Epoch 25/100
# 234/234 [==============================] - 1s 2ms/step - loss: 274.8957 - mean_squared_error: 274.8957 - val_loss: 222.2145 - val_mean_squared_error: 222.2145
# Epoch 26/100
# 234/234 [==============================] - 0s 2ms/step - loss: 259.4178 - mean_squared_error: 259.4178 - val_loss: 241.4397 - val_mean_squared_error: 241.4397
# Epoch 27/100
# 234/234 [==============================] - 0s 2ms/step - loss: 258.4157 - mean_squared_error: 258.4157 - val_loss: 196.8624 - val_mean_squared_error: 196.8624
# Epoch 28/100
# 234/234 [==============================] - 1s 2ms/step - loss: 249.9725 - mean_squared_error: 249.9725 - val_loss: 189.1180 - val_mean_squared_error: 189.1180
# Epoch 29/100
# 234/234 [==============================] - 1s 3ms/step - loss: 241.0194 - mean_squared_error: 241.0194 - val_loss: 200.0079 - val_mean_squared_error: 200.0079
# Epoch 30/100
# 234/234 [==============================] - 1s 2ms/step - loss: 231.0598 - mean_squared_error: 231.0598 - val_loss: 183.6634 - val_mean_squared_error: 183.6634
# Epoch 31/100
# 234/234 [==============================] - 1s 2ms/step - loss: 234.1153 - mean_squared_error: 234.1153 - val_loss: 171.0384 - val_mean_squared_error: 171.0384
# Epoch 32/100
# 234/234 [==============================] - 1s 2ms/step - loss: 230.8840 - mean_squared_error: 230.8840 - val_loss: 206.1008 - val_mean_squared_error: 206.1008
# Epoch 33/100
# 234/234 [==============================] - 1s 2ms/step - loss: 224.8538 - mean_squared_error: 224.8538 - val_loss: 165.2631 - val_mean_squared_error: 165.2631
# Epoch 34/100
# 234/234 [==============================] - 1s 2ms/step - loss: 220.9367 - mean_squared_error: 220.9367 - val_loss: 177.2041 - val_mean_squared_error: 177.2041
# Epoch 35/100
# 234/234 [==============================] - 1s 2ms/step - loss: 223.3874 - mean_squared_error: 223.3874 - val_loss: 161.7452 - val_mean_squared_error: 161.7452
# Epoch 36/100
# 234/234 [==============================] - 1s 2ms/step - loss: 216.2089 - mean_squared_error: 216.2089 - val_loss: 158.1607 - val_mean_squared_error: 158.1607
# Epoch 37/100
# 234/234 [==============================] - 0s 2ms/step - loss: 210.8436 - mean_squared_error: 210.8436 - val_loss: 156.5324 - val_mean_squared_error: 156.5324
# Epoch 38/100
# 234/234 [==============================] - 1s 2ms/step - loss: 216.8691 - mean_squared_error: 216.8691 - val_loss: 202.2614 - val_mean_squared_error: 202.2614
# Epoch 39/100
# 234/234 [==============================] - 0s 2ms/step - loss: 206.4904 - mean_squared_error: 206.4904 - val_loss: 152.8710 - val_mean_squared_error: 152.8710
# Epoch 40/100
# 234/234 [==============================] - 1s 2ms/step - loss: 209.1163 - mean_squared_error: 209.1163 - val_loss: 151.2882 - val_mean_squared_error: 151.2882
# Epoch 41/100
# 234/234 [==============================] - 0s 2ms/step - loss: 209.7804 - mean_squared_error: 209.7804 - val_loss: 150.9555 - val_mean_squared_error: 150.9555
# Epoch 42/100
# 234/234 [==============================] - 1s 2ms/step - loss: 213.8831 - mean_squared_error: 213.8831 - val_loss: 152.3824 - val_mean_squared_error: 152.3824
# Epoch 43/100
# 234/234 [==============================] - 0s 2ms/step - loss: 202.7494 - mean_squared_error: 202.7494 - val_loss: 162.5815 - val_mean_squared_error: 162.5815
# Epoch 44/100
# 234/234 [==============================] - 1s 2ms/step - loss: 203.6436 - mean_squared_error: 203.6436 - val_loss: 303.7278 - val_mean_squared_error: 303.7278
# Epoch 45/100
# 234/234 [==============================] - 1s 2ms/step - loss: 199.9232 - mean_squared_error: 199.9232 - val_loss: 147.8826 - val_mean_squared_error: 147.8826
# Epoch 46/100
# 234/234 [==============================] - 1s 2ms/step - loss: 195.4724 - mean_squared_error: 195.4724 - val_loss: 150.3185 - val_mean_squared_error: 150.3185
# Epoch 47/100
# 234/234 [==============================] - 1s 2ms/step - loss: 194.3177 - mean_squared_error: 194.3177 - val_loss: 166.9300 - val_mean_squared_error: 166.9300
# Epoch 48/100
# 234/234 [==============================] - 1s 2ms/step - loss: 195.5066 - mean_squared_error: 195.5066 - val_loss: 150.1657 - val_mean_squared_error: 150.1657
# Epoch 49/100
# 234/234 [==============================] - 1s 2ms/step - loss: 195.9815 - mean_squared_error: 195.9815 - val_loss: 158.2120 - val_mean_squared_error: 158.2120
# Epoch 50/100
# 234/234 [==============================] - 1s 2ms/step - loss: 193.7411 - mean_squared_error: 193.7411 - val_loss: 147.4281 - val_mean_squared_error: 147.4281
# Epoch 51/100
# 234/234 [==============================] - 1s 2ms/step - loss: 196.5921 - mean_squared_error: 196.5921 - val_loss: 148.7360 - val_mean_squared_error: 148.7360
# Epoch 52/100
# 234/234 [==============================] - 1s 2ms/step - loss: 196.0610 - mean_squared_error: 196.0610 - val_loss: 147.9554 - val_mean_squared_error: 147.9554
# Epoch 53/100
# 234/234 [==============================] - 1s 2ms/step - loss: 188.0568 - mean_squared_error: 188.0568 - val_loss: 146.4668 - val_mean_squared_error: 146.4668
# Epoch 54/100
# 234/234 [==============================] - 1s 2ms/step - loss: 196.4962 - mean_squared_error: 196.4962 - val_loss: 147.2172 - val_mean_squared_error: 147.2172
# Epoch 55/100
# 234/234 [==============================] - 1s 2ms/step - loss: 199.8249 - mean_squared_error: 199.8249 - val_loss: 149.4292 - val_mean_squared_error: 149.4292
# Epoch 56/100
# 234/234 [==============================] - 0s 2ms/step - loss: 195.9791 - mean_squared_error: 195.9791 - val_loss: 144.4499 - val_mean_squared_error: 144.4499
# Epoch 57/100
# 234/234 [==============================] - 1s 2ms/step - loss: 192.9882 - mean_squared_error: 192.9882 - val_loss: 144.0351 - val_mean_squared_error: 144.0351
# Epoch 58/100
# 234/234 [==============================] - 0s 2ms/step - loss: 192.3769 - mean_squared_error: 192.3769 - val_loss: 150.4461 - val_mean_squared_error: 150.4461
# Epoch 59/100
# 234/234 [==============================] - 1s 2ms/step - loss: 193.7864 - mean_squared_error: 193.7864 - val_loss: 150.5876 - val_mean_squared_error: 150.5876
# Epoch 60/100
# 234/234 [==============================] - 0s 2ms/step - loss: 191.0849 - mean_squared_error: 191.0849 - val_loss: 146.5506 - val_mean_squared_error: 146.5506
# Epoch 61/100
# 234/234 [==============================] - 0s 2ms/step - loss: 196.4459 - mean_squared_error: 196.4459 - val_loss: 144.1661 - val_mean_squared_error: 144.1661
# Epoch 62/100
# 234/234 [==============================] - 0s 2ms/step - loss: 192.1089 - mean_squared_error: 192.1089 - val_loss: 147.2820 - val_mean_squared_error: 147.2820

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# 예측 수행
y_pred_lstm = lstm_model.predict(X_test)
y_pred_gru = gru_model.predict(X_test)
y_pred_rnn = rnn_model.predict(X_test)

# MSE 계산
lstm_mse = mean_squared_error(y_test, y_pred_lstm)
gru_mse = mean_squared_error(y_test, y_pred_gru)
rnn_mse = mean_squared_error(y_test, y_pred_rnn)

# MAE 계산
lstm_mae = mean_absolute_error(y_test, y_pred_lstm)
gru_mae = mean_absolute_error(y_test, y_pred_gru)
rnn_mae = mean_absolute_error(y_test, y_pred_rnn)

# R^2 Score 계산
lstm_r2 = r2_score(y_test, y_pred_lstm)
gru_r2 = r2_score(y_test, y_pred_gru)
rnn_r2 = r2_score(y_test, y_pred_rnn)

print(f"LSTM MSE: {lstm_mse}, MAE: {lstm_mae}, R^2: {lstm_r2}")
print(f"GRU MSE: {gru_mse}, MAE: {gru_mae}, R^2: {gru_r2}")
print(f"RNN MSE: {rnn_mse}, MAE: {rnn_mae}, R^2: {rnn_r2}")
# Out:
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 2ms/step
# 59/59 [==============================] - 0s 942us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 y_pred_rnn = rnn_model.predict(X_test)
#       8 # MSE 계산
# ----> 9 lstm_mse = mean_squared_error(y_test, y_pred_lstm)
#      10 gru_mse = mean_squared_error(y_test, y_pred_gru)
#      11 rnn_mse = mean_squared_error(y_test, y_pred_rnn)
#
# NameError: name 'mean_squared_error' is not defined

# %%
# 4. 학습 및 검증 손실 시각화

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))

# Epochs 기준 그래프
plt.subplot(2, 2, 1)
plt.plot(rnn_history.history['loss'], label='tanh train', color='blue')
plt.plot(rnn_history.history['val_loss'], label='tanh valid', color='blue', linestyle='--')
plt.plot(gru_history.history['loss'], label='GRU train', color='green')
plt.plot(gru_history.history['val_loss'], label='GRU valid', color='green', linestyle='--')
plt.plot(lstm_history.history['loss'], label='LSTM train', color='purple')
plt.plot(lstm_history.history['val_loss'], label='LSTM valid', color='purple', linestyle='--')
plt.yscale('log')
plt.title('Per epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 시간 기준 그래프
plt.subplot(2, 2, 2)
plt.plot(np.cumsum(rnn_history.history['loss']), label='tanh train', color='blue')
plt.plot(np.cumsum(rnn_history.history['val_loss']), label='tanh valid', color='blue', linestyle='--')
plt.plot(np.cumsum(gru_history.history['loss']), label='GRU train', color='green')
plt.plot(np.cumsum(gru_history.history['val_loss']), label='GRU valid', color='green', linestyle='--')
plt.plot(np.cumsum(lstm_history.history['loss']), label='LSTM train', color='purple')
plt.plot(np.cumsum(lstm_history.history['val_loss']), label='LSTM valid', color='purple', linestyle='--')
plt.yscale('log')
plt.title('Wall Clock Time (seconds)')
plt.xlabel('Epochs')
plt.ylabel('Cumulative Loss')
plt.legend()

# 두 그래프를 합친 제목 추가
plt.suptitle('Air Quality [Optimize: RMSprop]', fontsize=16)

plt.tight_layout(rect=[0, 0, 1, 0.95])  # suptitle과 그래프가 겹치지 않도록 조정
plt.show()

# %%
# LSTM 모델 정의
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# GRU 모델 정의
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(50, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# SimpleRNN(tanh) 모델 정의
def build_rnn_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(50, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# 조기 종료 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련
lstm_model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
gru_model = build_gru_model((X_train.shape[1], X_train.shape[2]))
rnn_model = build_rnn_model((X_train.shape[1], X_train.shape[2]))

lstm_history = lstm_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
gru_history = gru_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
rnn_history = rnn_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])

# %%
# 4. 학습 및 검증 손실 시각화

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
# Epochs 기준 그래프
plt.subplot(2, 2, 1)
plt.plot(rnn_history.history['loss'], label='tanh train', color='blue')
plt.plot(rnn_history.history['val_loss'], label='tanh valid', color='blue', linestyle='--')
plt.plot(gru_history.history['loss'], label='GRU train', color='green')
plt.plot(gru_history.history['val_loss'], label='GRU valid', color='green', linestyle='--')
plt.plot(lstm_history.history['loss'], label='LSTM train', color='purple')
plt.plot(lstm_history.history['val_loss'], label='LSTM valid', color='purple', linestyle='--')
plt.yscale('log')
plt.title('Per epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 시간 기준 그래프
plt.subplot(2, 2, 2)
plt.plot(np.cumsum(rnn_history.history['loss']), label='tanh train', color='blue')
plt.plot(np.cumsum(rnn_history.history['val_loss']), label='tanh valid', color='blue', linestyle='--')
plt.plot(np.cumsum(gru_history.history['loss']), label='GRU train', color='green')
plt.plot(np.cumsum(gru_history.history['val_loss']), label='GRU valid', color='green', linestyle='--')
plt.plot(np.cumsum(lstm_history.history['loss']), label='LSTM train', color='purple')
plt.plot(np.cumsum(lstm_history.history['val_loss']), label='LSTM valid', color='purple', linestyle='--')
plt.yscale('log')
plt.title('Wall Clock Time (seconds)')
plt.xlabel('Epochs')
plt.ylabel('Cumulative Loss')
plt.legend()

# 두 그래프를 합친 제목 추가
plt.suptitle('Air Quality [Optimize: adam]', fontsize=16)

plt.tight_layout(rect=[0, 0, 1, 0.95])  # suptitle과 그래프가 겹치지 않도록 조정
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 예측 수행
y_pred_lstm = lstm_model.predict(X_test)
y_pred_gru = gru_model.predict(X_test)
y_pred_rnn = rnn_model.predict(X_test)

# MSE 계산
lstm_mse = mean_squared_error(y_test, y_pred_lstm)
gru_mse = mean_squared_error(y_test, y_pred_gru)
rnn_mse = mean_squared_error(y_test, y_pred_rnn)

# MAE 계산
lstm_mae = mean_absolute_error(y_test, y_pred_lstm)
gru_mae = mean_absolute_error(y_test, y_pred_gru)
rnn_mae = mean_absolute_error(y_test, y_pred_rnn)

# R^2 Score 계산
lstm_r2 = r2_score(y_test, y_pred_lstm)
gru_r2 = r2_score(y_test, y_pred_gru)
rnn_r2 = r2_score(y_test, y_pred_rnn)

print(f"LSTM MSE: {lstm_mse}, MAE: {lstm_mae}, R^2: {lstm_r2}")
print(f"GRU MSE: {gru_mse}, MAE: {gru_mae}, R^2: {gru_r2}")
print(f"RNN MSE: {rnn_mse}, MAE: {rnn_mae}, R^2: {rnn_r2}")
