# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
combined_cycle_power_plant = fetch_ucirepo(id=294) 
  
# data (as pandas dataframes) 
X = combined_cycle_power_plant.data.features 
y = combined_cycle_power_plant.data.targets

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np
# y를 Numpy 배열로 변환
y = y.values
# 데이터를 0과 1 사이로 스케일링
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)


# 시계열 데이터로 변환하기 위해 시퀀스 생성
time_steps = 10

def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps), :])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y, time_steps)

# 데이터셋을 훈련, 검증, 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, shuffle=False)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout
from keras.optimizers import RMSprop
from keras.metrics import MeanSquaredError
from keras.callbacks import EarlyStopping

# LSTM 모델 정의
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=RMSprop(), loss='mse', metrics=[MeanSquaredError()])
    return model

# GRU 모델 정의
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(50, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=RMSprop(), loss='mse', metrics=[MeanSquaredError()])
    return model

# SimpleRNN(tanh) 모델 정의
def build_rnn_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(50, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=RMSprop(), loss='mse', metrics=[MeanSquaredError()])
    return model

# 조기 종료 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련
lstm_model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
gru_model = build_gru_model((X_train.shape[1], X_train.shape[2]))
rnn_model = build_rnn_model((X_train.shape[1], X_train.shape[2]))

lstm_history = lstm_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
gru_history = gru_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
rnn_history = rnn_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 239/239 [==============================] - 2s 4ms/step - loss: 24437.0645 - mean_squared_error: 24437.0645 - val_loss: 3669.2222 - val_mean_squared_error: 3669.2222
# Epoch 2/100
# 239/239 [==============================] - 1s 3ms/step - loss: 5483.2437 - mean_squared_error: 5483.2437 - val_loss: 2153.5344 - val_mean_squared_error: 2153.5344
# Epoch 3/100
# 239/239 [==============================] - 1s 3ms/step - loss: 4779.5850 - mean_squared_error: 4779.5850 - val_loss: 2921.9478 - val_mean_squared_error: 2921.9478
# Epoch 4/100
# 239/239 [==============================] - 1s 3ms/step - loss: 4328.3721 - mean_squared_error: 4328.3721 - val_loss: 822.2003 - val_mean_squared_error: 822.2003
# Epoch 5/100
# 239/239 [==============================] - 1s 3ms/step - loss: 4079.6089 - mean_squared_error: 4079.6089 - val_loss: 771.7371 - val_mean_squared_error: 771.7371
# Epoch 6/100
# 239/239 [==============================] - 1s 4ms/step - loss: 3937.3835 - mean_squared_error: 3937.3835 - val_loss: 1433.3728 - val_mean_squared_error: 1433.3728
# Epoch 7/100
# 239/239 [==============================] - 1s 4ms/step - loss: 3766.1353 - mean_squared_error: 3766.1353 - val_loss: 1702.1825 - val_mean_squared_error: 1702.1825
# Epoch 8/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3708.2417 - mean_squared_error: 3708.2417 - val_loss: 533.7955 - val_mean_squared_error: 533.7955
# Epoch 9/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3605.2104 - mean_squared_error: 3605.2104 - val_loss: 908.3674 - val_mean_squared_error: 908.3674
# Epoch 10/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3552.9775 - mean_squared_error: 3552.9775 - val_loss: 2430.8494 - val_mean_squared_error: 2430.8494
# Epoch 11/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3342.2078 - mean_squared_error: 3342.2078 - val_loss: 3154.3330 - val_mean_squared_error: 3154.3330
# Epoch 12/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3320.2524 - mean_squared_error: 3320.2524 - val_loss: 549.5379 - val_mean_squared_error: 549.5379
# Epoch 13/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3251.0073 - mean_squared_error: 3251.0073 - val_loss: 2143.7336 - val_mean_squared_error: 2143.7336
# Epoch 1/100
# 239/239 [==============================] - 2s 4ms/step - loss: 31139.8320 - mean_squared_error: 31139.8320 - val_loss: 1636.0220 - val_mean_squared_error: 1636.0220
# Epoch 2/100
# 239/239 [==============================] - 1s 3ms/step - loss: 4825.0391 - mean_squared_error: 4825.0391 - val_loss: 934.9551 - val_mean_squared_error: 934.9551
# Epoch 3/100
# 239/239 [==============================] - 1s 3ms/step - loss: 4268.9717 - mean_squared_error: 4268.9717 - val_loss: 1297.3140 - val_mean_squared_error: 1297.3140
# Epoch 4/100
# 239/239 [==============================] - 1s 3ms/step - loss: 4024.9719 - mean_squared_error: 4024.9719 - val_loss: 911.9160 - val_mean_squared_error: 911.9160
# Epoch 5/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3820.7744 - mean_squared_error: 3820.7744 - val_loss: 4033.1438 - val_mean_squared_error: 4033.1438
# Epoch 6/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3651.4163 - mean_squared_error: 3651.4163 - val_loss: 1319.2737 - val_mean_squared_error: 1319.2737
# Epoch 7/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3614.0208 - mean_squared_error: 3614.0208 - val_loss: 2763.1694 - val_mean_squared_error: 2763.1694
# Epoch 8/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3549.5132 - mean_squared_error: 3549.5132 - val_loss: 521.0239 - val_mean_squared_error: 521.0239
# Epoch 9/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3452.2292 - mean_squared_error: 3452.2292 - val_loss: 619.1391 - val_mean_squared_error: 619.1391
# Epoch 10/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3311.5632 - mean_squared_error: 3311.5632 - val_loss: 539.7347 - val_mean_squared_error: 539.7347
# Epoch 11/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3318.8999 - mean_squared_error: 3318.8999 - val_loss: 3155.5244 - val_mean_squared_error: 3155.5244
# Epoch 12/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3289.1562 - mean_squared_error: 3289.1562 - val_loss: 1295.4406 - val_mean_squared_error: 1295.4406
# Epoch 13/100
# 239/239 [==============================] - 1s 3ms/step - loss: 3272.2922 - mean_squared_error: 3272.2922 - val_loss: 709.5434 - val_mean_squared_error: 709.5434
# Epoch 1/100
# 239/239 [==============================] - 1s 3ms/step - loss: 22823.3477 - mean_squared_error: 22823.3477 - val_loss: 2849.8206 - val_mean_squared_error: 2849.8206
# Epoch 2/100
# 239/239 [==============================] - 1s 2ms/step - loss: 4624.6152 - mean_squared_error: 4624.6152 - val_loss: 2703.7898 - val_mean_squared_error: 2703.7898
# Epoch 3/100
# 239/239 [==============================] - 0s 2ms/step - loss: 4143.3945 - mean_squared_error: 4143.3945 - val_loss: 1868.4636 - val_mean_squared_error: 1868.4636
# Epoch 4/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3817.2754 - mean_squared_error: 3817.2754 - val_loss: 1222.2015 - val_mean_squared_error: 1222.2015
# Epoch 5/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3523.5056 - mean_squared_error: 3523.5056 - val_loss: 2843.5457 - val_mean_squared_error: 2843.5457
# Epoch 6/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3415.9900 - mean_squared_error: 3415.9900 - val_loss: 1721.1389 - val_mean_squared_error: 1721.1389
# Epoch 7/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3425.6262 - mean_squared_error: 3425.6262 - val_loss: 2908.4763 - val_mean_squared_error: 2908.4763
# Epoch 8/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3331.0220 - mean_squared_error: 3331.0220 - val_loss: 503.8992 - val_mean_squared_error: 503.8992
# Epoch 9/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3244.6372 - mean_squared_error: 3244.6372 - val_loss: 1352.6602 - val_mean_squared_error: 1352.6602
# Epoch 10/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3170.0037 - mean_squared_error: 3170.0037 - val_loss: 938.8371 - val_mean_squared_error: 938.8371
# Epoch 11/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3181.2207 - mean_squared_error: 3181.2207 - val_loss: 440.7155 - val_mean_squared_error: 440.7155
# Epoch 12/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3151.5059 - mean_squared_error: 3151.5059 - val_loss: 436.9913 - val_mean_squared_error: 436.9913
# Epoch 13/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3034.1804 - mean_squared_error: 3034.1804 - val_loss: 1397.4705 - val_mean_squared_error: 1397.4705
# Epoch 14/100
# 239/239 [==============================] - 0s 2ms/step - loss: 3101.5947 - mean_squared_error: 3101.5947 - val_loss: 505.7376 - val_mean_squared_error: 505.7376
# Epoch 15/100
# 239/239 [==============================] - 0s 2ms/step - loss: 2956.0625 - mean_squared_error: 2956.0625 - val_loss: 528.6312 - val_mean_squared_error: 528.6312
# Epoch 16/100
# 239/239 [==============================] - 0s 2ms/step - loss: 2912.3562 - mean_squared_error: 2912.3562 - val_loss: 676.5575 - val_mean_squared_error: 676.5575
# Epoch 17/100
# 239/239 [==============================] - 0s 2ms/step - loss: 2958.5234 - mean_squared_error: 2958.5234 - val_loss: 906.9990 - val_mean_squared_error: 906.9990

# %%
from sklearn.metrics import mean_squared_error
# 모델 평가
rnn_pred = rnn_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
gru_pred = gru_model.predict(X_test)

# MSE 계산
rnn_mse = mean_squared_error(y_test, rnn_pred)
lstm_mse = mean_squared_error(y_test, lstm_pred)
gru_mse = mean_squared_error(y_test, gru_pred)

print(f"RNN MSE: {rnn_mse}")
print(f"LSTM MSE: {lstm_mse}")
print(f"GRU MSE: {gru_mse}")
# Out:
# 60/60 [==============================] - 0s 932us/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# RNN MSE: 436.99137522304693
# LSTM MSE: 533.7956408848663
# GRU MSE: 521.0239916285806

# %%
import matplotlib.pyplot as plt

# 학습 및 검증 손실 시각화
plt.figure(figsize=(12, 8))

# Epochs 기준 그래프
plt.subplot(2, 2, 1)
plt.plot(rnn_history.history['loss'], label='tanh train', color='blue')
plt.plot(rnn_history.history['val_loss'], label='tanh valid', color='blue', linestyle='--')
plt.plot(gru_history.history['loss'], label='GRU train', color='green')
plt.plot(gru_history.history['val_loss'], label='GRU valid', color='green', linestyle='--')
plt.plot(lstm_history.history['loss'], label='LSTM train', color='purple')
plt.plot(lstm_history.history['val_loss'], label='LSTM valid', color='purple', linestyle='--')
plt.yscale('log')
plt.title('Per epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 시간 기준 그래프
plt.subplot(2, 2, 2)
plt.plot(np.cumsum(rnn_history.history['loss']), label='tanh train', color='blue')
plt.plot(np.cumsum(rnn_history.history['val_loss']), label='tanh valid', color='blue', linestyle='--')
plt.plot(np.cumsum(gru_history.history['loss']), label='GRU train', color='green')
plt.plot(np.cumsum(gru_history.history['val_loss']), label='GRU valid', color='green', linestyle='--')
plt.plot(np.cumsum(lstm_history.history['loss']), label='LSTM train', color='purple')
plt.plot(np.cumsum(lstm_history.history['val_loss']), label='LSTM valid', color='purple', linestyle='--')
plt.yscale('log')
plt.title('Wall Clock Time (seconds)')
plt.xlabel('Epochs')
plt.ylabel('Cumulative Loss')
plt.legend()

# 두 그래프를 합친 제목 추가
plt.suptitle('Combined Cycle Power Plant', fontsize=16)

plt.tight_layout(rect=[0, 0, 1, 0.95])  # suptitle과 그래프가 겹치지 않도록 조정
plt.show()

# %%
def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps), :])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y, time_steps)

# 데이터셋을 훈련, 검증, 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, shuffle=False)

# 3. LSTM 모델 정의 (드롭아웃과 조기 종료 포함)
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# 4. GRU 모델 정의 (드롭아웃과 조기 종료 포함)
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(50, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model
    
# RNN 모델 정의 (드롭아웃과 조기 종료 포함)
def build_rnn_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(50, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# 조기 종료 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련 (조기 종료 콜백 추가)
lstm_model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
gru_model = build_gru_model((X_train.shape[1], X_train.shape[2]))
rnn_model = build_rnn_model((X_train.shape[1], X_train.shape[2]))

lstm_history = lstm_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=1)
gru_history = gru_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=1)
rnn_history = rnn_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# 6. 모델 평가
lstm_loss, lstm_mse = lstm_model.evaluate(X_test, y_test, verbose=0)
gru_loss, gru_mse = gru_model.evaluate(X_test, y_test, verbose=0)
rnn_loss, rnn_mse = rnn_model.evaluate(X_test, y_test, verbose=0)

print(f"LSTM Model - Test Loss: {lstm_loss}, Test MSE: {lstm_mse}")
print(f"GRU Model - Test Loss: {gru_loss}, Test MSE: {gru_mse}")
print(f"RNN Model - Test Loss: {rnn_loss}, Test MSE: {rnn_mse}")
# Out:
# Epoch 1/20
# 239/239 [==============================] - 3s 6ms/step - loss: 45141.6328 - mean_squared_error: 45141.6328 - val_loss: 2387.0195 - val_mean_squared_error: 2387.0195
# Epoch 2/20
# 239/239 [==============================] - 1s 4ms/step - loss: 4526.6562 - mean_squared_error: 4526.6562 - val_loss: 1212.5720 - val_mean_squared_error: 1212.5720
# Epoch 3/20
# 239/239 [==============================] - 1s 5ms/step - loss: 3607.4741 - mean_squared_error: 3607.4741 - val_loss: 756.2816 - val_mean_squared_error: 756.2816
# Epoch 4/20
# 239/239 [==============================] - 1s 5ms/step - loss: 3040.3486 - mean_squared_error: 3040.3486 - val_loss: 568.5341 - val_mean_squared_error: 568.5341
# Epoch 5/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2817.6553 - mean_squared_error: 2817.6553 - val_loss: 463.5331 - val_mean_squared_error: 463.5331
# Epoch 6/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2610.3081 - mean_squared_error: 2610.3081 - val_loss: 857.4116 - val_mean_squared_error: 857.4116
# Epoch 7/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2639.5581 - mean_squared_error: 2639.5581 - val_loss: 471.7282 - val_mean_squared_error: 471.7282
# Epoch 8/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2500.2273 - mean_squared_error: 2500.2273 - val_loss: 837.4132 - val_mean_squared_error: 837.4132
# Epoch 9/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2492.0750 - mean_squared_error: 2492.0750 - val_loss: 788.6500 - val_mean_squared_error: 788.6500
# Epoch 10/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2475.8650 - mean_squared_error: 2475.8650 - val_loss: 322.5900 - val_mean_squared_error: 322.5900
# Epoch 11/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2549.9233 - mean_squared_error: 2549.9233 - val_loss: 336.4444 - val_mean_squared_error: 336.4444
# Epoch 12/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2457.7566 - mean_squared_error: 2457.7566 - val_loss: 311.3384 - val_mean_squared_error: 311.3384
# Epoch 13/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2495.5103 - mean_squared_error: 2495.5103 - val_loss: 752.2420 - val_mean_squared_error: 752.2420
# Epoch 14/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2521.1758 - mean_squared_error: 2521.1758 - val_loss: 347.8585 - val_mean_squared_error: 347.8585
# Epoch 15/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2495.1123 - mean_squared_error: 2495.1123 - val_loss: 304.0536 - val_mean_squared_error: 304.0536
# Epoch 16/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2421.0688 - mean_squared_error: 2421.0688 - val_loss: 414.7104 - val_mean_squared_error: 414.7104
# Epoch 17/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2367.5471 - mean_squared_error: 2367.5471 - val_loss: 369.5891 - val_mean_squared_error: 369.5891
# Epoch 18/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2339.7439 - mean_squared_error: 2339.7439 - val_loss: 324.1485 - val_mean_squared_error: 324.1485
# Epoch 19/20
# 239/239 [==============================] - 1s 5ms/step - loss: 2445.6990 - mean_squared_error: 2445.6990 - val_loss: 391.0614 - val_mean_squared_error: 391.0614
# Epoch 20/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2392.8357 - mean_squared_error: 2392.8357 - val_loss: 388.7137 - val_mean_squared_error: 388.7137
# Epoch 1/20
# 239/239 [==============================] - 2s 5ms/step - loss: 54076.9922 - mean_squared_error: 54076.9922 - val_loss: 1224.2977 - val_mean_squared_error: 1224.2977
# Epoch 2/20
# 239/239 [==============================] - 1s 4ms/step - loss: 3509.5291 - mean_squared_error: 3509.5291 - val_loss: 931.5219 - val_mean_squared_error: 931.5218
# Epoch 3/20
# 239/239 [==============================] - 1s 3ms/step - loss: 3149.0818 - mean_squared_error: 3149.0818 - val_loss: 698.5988 - val_mean_squared_error: 698.5988
# Epoch 4/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2809.0876 - mean_squared_error: 2809.0876 - val_loss: 645.2883 - val_mean_squared_error: 645.2883
# Epoch 5/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2708.6672 - mean_squared_error: 2708.6672 - val_loss: 476.1633 - val_mean_squared_error: 476.1633
# Epoch 6/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2600.5225 - mean_squared_error: 2600.5225 - val_loss: 706.5536 - val_mean_squared_error: 706.5536
# Epoch 7/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2639.0247 - mean_squared_error: 2639.0247 - val_loss: 1936.3339 - val_mean_squared_error: 1936.3339
# Epoch 8/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2509.1826 - mean_squared_error: 2509.1826 - val_loss: 338.2374 - val_mean_squared_error: 338.2374
# Epoch 9/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2495.0576 - mean_squared_error: 2495.0576 - val_loss: 442.3533 - val_mean_squared_error: 442.3533
# Epoch 10/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2493.6951 - mean_squared_error: 2493.6951 - val_loss: 547.1829 - val_mean_squared_error: 547.1829
# Epoch 11/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2343.1182 - mean_squared_error: 2343.1182 - val_loss: 740.0769 - val_mean_squared_error: 740.0769
# Epoch 12/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2334.5762 - mean_squared_error: 2334.5762 - val_loss: 629.4185 - val_mean_squared_error: 629.4185
# Epoch 13/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2362.5579 - mean_squared_error: 2362.5579 - val_loss: 554.0945 - val_mean_squared_error: 554.0945
# Epoch 14/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2265.1929 - mean_squared_error: 2265.1929 - val_loss: 382.4028 - val_mean_squared_error: 382.4028
# Epoch 15/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2255.9402 - mean_squared_error: 2255.9402 - val_loss: 304.0322 - val_mean_squared_error: 304.0322
# Epoch 16/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2364.4570 - mean_squared_error: 2364.4570 - val_loss: 392.1994 - val_mean_squared_error: 392.1994
# Epoch 17/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2246.7019 - mean_squared_error: 2246.7019 - val_loss: 389.4240 - val_mean_squared_error: 389.4240
# Epoch 18/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2250.1519 - mean_squared_error: 2250.1519 - val_loss: 324.4810 - val_mean_squared_error: 324.4810
# Epoch 19/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2322.0632 - mean_squared_error: 2322.0632 - val_loss: 498.2797 - val_mean_squared_error: 498.2797
# Epoch 20/20
# 239/239 [==============================] - 1s 4ms/step - loss: 2301.2979 - mean_squared_error: 2301.2979 - val_loss: 361.0449 - val_mean_squared_error: 361.0449
# Epoch 1/20
# 239/239 [==============================] - 1s 3ms/step - loss: 39461.0469 - mean_squared_error: 39461.0469 - val_loss: 1293.6641 - val_mean_squared_error: 1293.6641
# Epoch 2/20
# 239/239 [==============================] - 1s 2ms/step - loss: 4072.1094 - mean_squared_error: 4072.1094 - val_loss: 1008.9745 - val_mean_squared_error: 1008.9745
# Epoch 3/20
# 239/239 [==============================] - 1s 2ms/step - loss: 3358.7390 - mean_squared_error: 3358.7390 - val_loss: 654.3918 - val_mean_squared_error: 654.3918
# Epoch 4/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2865.5793 - mean_squared_error: 2865.5793 - val_loss: 563.3047 - val_mean_squared_error: 563.3047
# Epoch 5/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2836.0317 - mean_squared_error: 2836.0317 - val_loss: 616.1832 - val_mean_squared_error: 616.1832
# Epoch 6/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2686.4277 - mean_squared_error: 2686.4277 - val_loss: 679.1357 - val_mean_squared_error: 679.1357
# Epoch 7/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2586.5032 - mean_squared_error: 2586.5032 - val_loss: 662.3599 - val_mean_squared_error: 662.3599
# Epoch 8/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2489.2844 - mean_squared_error: 2489.2844 - val_loss: 438.6679 - val_mean_squared_error: 438.6679
# Epoch 9/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2536.3323 - mean_squared_error: 2536.3323 - val_loss: 429.7673 - val_mean_squared_error: 429.7673
# Epoch 10/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2416.0945 - mean_squared_error: 2416.0945 - val_loss: 495.1827 - val_mean_squared_error: 495.1827
# Epoch 11/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2381.1604 - mean_squared_error: 2381.1604 - val_loss: 469.4192 - val_mean_squared_error: 469.4192
# Epoch 12/20
# 239/239 [==============================] - 1s 3ms/step - loss: 2394.8777 - mean_squared_error: 2394.8777 - val_loss: 642.2180 - val_mean_squared_error: 642.2180
# Epoch 13/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2404.3347 - mean_squared_error: 2404.3347 - val_loss: 387.4824 - val_mean_squared_error: 387.4824
# Epoch 14/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2408.5491 - mean_squared_error: 2408.5491 - val_loss: 406.0610 - val_mean_squared_error: 406.0610
# Epoch 15/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2470.1143 - mean_squared_error: 2470.1143 - val_loss: 480.6191 - val_mean_squared_error: 480.6191
# Epoch 16/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2378.5740 - mean_squared_error: 2378.5740 - val_loss: 431.1663 - val_mean_squared_error: 431.1663
# Epoch 17/20
# 239/239 [==============================] - 0s 2ms/step - loss: 2317.1543 - mean_squared_error: 2317.1543 - val_loss: 382.5752 - val_mean_squared_error: 382.5752
# Epoch 18/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2451.4866 - mean_squared_error: 2451.4866 - val_loss: 468.1953 - val_mean_squared_error: 468.1953
# Epoch 19/20
# 239/239 [==============================] - 1s 2ms/step - loss: 2434.8979 - mean_squared_error: 2434.8979 - val_loss: 349.0958 - val_mean_squared_error: 349.0958
# Epoch 20/20
# 239/239 [==============================] - 0s 2ms/step - loss: 2358.7483 - mean_squared_error: 2358.7483 - val_loss: 702.1419 - val_mean_squared_error: 702.1419
# LSTM Model - Test Loss: 388.7137451171875, Test MSE: 388.7137451171875
# GRU Model - Test Loss: 361.04486083984375, Test MSE: 361.04486083984375
# RNN Model - Test Loss: 702.1419067382812, Test MSE: 702.1419067382812

# %%
from sklearn.metrics import mean_squared_error
# 모델 평가
rnn_pred = rnn_model.predict(X_test)
lstm_pred = lstm_model.predict(X_test)
gru_pred = gru_model.predict(X_test)

# MSE 계산
rnn_mse = mean_squared_error(y_test, rnn_pred)
lstm_mse = mean_squared_error(y_test, lstm_pred)
gru_mse = mean_squared_error(y_test, gru_pred)

print(f"RNN MSE: {rnn_mse}")
print(f"LSTM MSE: {lstm_mse}")
print(f"GRU MSE: {gru_mse}")
# Out:
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# RNN MSE: 702.1419503522903
# LSTM MSE: 388.71381002735956
# GRU MSE: 361.04488841367885
